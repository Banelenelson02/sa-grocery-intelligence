# %%
import psycopg2

db_uri = "postgresql://postgres.pdowjhavuvnzotnzvwul:NELOS5827086816@aws-0-eu-west-1.pooler.supabase.com:5432/postgres"

try:
    connection = psycopg2.connect(db_uri)
    cursor = connection.cursor()

    cursor.execute("SELECT AVG(price_zar) FROM practice_prices WHERE product = 'Full Cream Milk 2L'")

    average_price = cursor.fetchone()

    print("Connection successful! The average milk price is:", average_price[0])

    cursor.close()
    connection.close()

except Exception as e:
    print("Connection failed:", e)
# Out:
# Connection successful! The average milk price is: 30.9920000000000000
